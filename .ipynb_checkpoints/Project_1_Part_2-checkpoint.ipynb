# %%
library('igraph')
library('Matrix')
library('pracma')

# %%
create_transition_matrix = function (g){
    
    # WARNING: make sure your graph is connected (you might input GCC of your graph)
    
    vs = V(g)
    n = vcount(g)
    adj = as_adjacency_matrix(g)
    adj[diag(rowSums(adj) == 0)] = 1  # handle if the user is using the function for networks with isolated nodes by creating self-edges
    z = matrix(rowSums(adj, , 1))
    
    transition_matrix = adj / repmat(z, 1, n)  # normalize to get probabilities
    
    return(transition_matrix)
}

# %% [markdown]
# ### Part 2. Random Walk on Networks

# %% [markdown]
# #### 1. Random walk on Erdös-Rényi networks

# %% [markdown]
# **a. Create an undirected random network with 1000 nodes and p = 0.01**

# %%
set.seed(1)
g1 <- erdos.renyi.game(1000, p = 0.01, directed=F)
plot(g1,vertex.size=4, vertex.label.cex=0.3)
# Out:
# Plot with title ""

# %% [markdown]
# **b. **

# %%
random_walk = function (g, num_steps, start_node, transition_matrix = NULL){
    if(is.null(transition_matrix))
        transition_matrix = create_transition_matrix(g)
        
    v = start_node
    for(i in 1:num_steps){
        # fprintf('Step %d: %d\n', i, v)  # COMMENT THIS
        PMF = transition_matrix[v, ]
        v = sample(1:vcount(g), 1, prob = PMF)        
    }
    
    return(v)
}

# %%
RowVar <- function(x) {
  rowSums((x - rowMeans(x))^2)/(dim(x)[2] - 1)
}

# %%
set.seed(1)
tm <- create_transition_matrix(g1)
g1_vcount = vcount(g1)

s_t_matrix <- c()
last_deg <- c()
for (init_node in sample(1:g1_vcount, 300)){
    trial_s = c()
    last = init_node
    for (t in 1:300){
        PMF = tm[last, ]
        last = sample(1:g1_vcount, 1, prob = PMF)  
        shortestpath = shortest.paths(g1, init_node, last)
        trial_s = c(trial_s, shortestpath)
    }
    last_deg <- c(last_deg, degree(g1, last))
    s_t_matrix <- cbind(s_t_matrix, trial_s)
}
s_t <- rowMeans(s_t_matrix)
var_t <- RowVar(s_t_matrix)

# %%
plot(s_t, main="s(t) of G(1000, p=0.01)",xlab="step",ylab="avg distance",type="l")
plot(var_t, main="var(t) of G(1000, p=0.01)",xlab="step",ylab="variance",type="l")
# Out:
# Plot with title "s(t) of G(1000, p=0.01)"
# Plot with title "var(t) of G(1000, p=0.01)"

# %%
print(s_t[1:40])
# Out:
#  [1] 1.000000 1.793333 2.556667 2.913333 3.056667 3.120000 3.136667 3.106667
#  [9] 3.160000 3.126667 3.196667 3.213333 3.190000 3.220000 3.270000 3.223333
# [17] 3.223333 3.256667 3.183333 3.186667 3.230000 3.213333 3.160000 3.213333
# [25] 3.170000 3.156667 3.216667 3.220000 3.206667 3.190000 3.186667 3.140000
# [33] 3.166667 3.150000 3.176667 3.170000 3.153333 3.203333 3.206667 3.206667

# %% [markdown]
# **c.**

# %%
hist(last_deg, main="degree of last node",xlab="degree",ylab="number",xlim=c(0,22))
hist(degree(g1), main="degree of graph nodes",xlab="degree",ylab="number",xlim=c(0,22))
# Out:
# Plot with title "degree of last node"
# Plot with title "degree of graph nodes"

# %% [markdown]
# **d.**

# %%
set.seed(1)
g2 <- erdos.renyi.game(100, p = 0.01, directed=F)
plot(g2,vertex.size=4, vertex.label.cex=0.3)

tmp.components <- clusters(g2)
gcc_s <- which.max(tmp.components$csize)
gcc <- induced.subgraph(g2, which(tmp.components$membership == gcc_s))

plot(gcc,vertex.size=4, vertex.label.cex=0.3)

tm2 <- create_transition_matrix(gcc)
g2_vcount = vcount(gcc)

s_t_matrix <- c()
for (init_node in sample(1:g2_vcount, size=100, replace=TRUE)){
    trial_s = c()
    last = init_node
    for (t in 1:300){
        PMF = tm2[last, ]
        last = sample(1:g2_vcount, 1, prob = PMF)  
        shortestpath = shortest.paths(gcc, init_node, last)
        trial_s = c(trial_s, shortestpath)
    }
    s_t_matrix <- cbind(s_t_matrix, trial_s)
}
s_t2 <- rowMeans(s_t_matrix)
var_t2 <- RowVar(s_t_matrix)
# Out:
# Plot with title ""
# Plot with title ""

# %%
plot(s_t2, main="s(t) of G(100, p=0.01)",xlab="step",ylab="avg distance",type="l")
plot(var_t2, main="var(t) of G(100, p=0.01)",xlab="step",ylab="variance",type="l")
# Out:
# Plot with title "s(t) of G(100, p=0.01)"
# Plot with title "var(t) of G(100, p=0.01)"

# %%
shortest_path_matrix = function (g){

    n = vcount(g)
    adj = as_adjacency_matrix(g)
    adj[diag(rowSums(adj) == 0)] = 1  # handle if the user is using the function for networks with isolated nodes by creating self-edges
    d = diameter(g)
    sp = adj
    tmp = adj>0
    for (i in 2:d){
        tmp = (adj %*% tmp) > 0
        sp[!(sp > 0) & tmp] = sp[!(sp > 0) & tmp] + i
    }
    sp[diag(rep(1, n)==1)] = 0
    return(sp)
}

# %%
if(!file.exists("./g3.RData")){
    set.seed(1)
    g3 <- erdos.renyi.game(10000, p = 0.01, directed=F)
    # plot(g3,vertex.size=4, vertex.label.cex=0.3)
    # sp3 <- shortest_path_matrix(g3)
    sp3 <- shortest.paths(g3)
    g3_vcount = vcount(g3)

    set.seed(1)
    s_t_matrix <- c()
    for (init_node in sample(1:g3_vcount, 100)){
        trial_s = c()

        last = init_node
        for (t in 1:300){
            neigh = neighbors(g3, last)
            last = sample(as_ids(neigh), 1)
            shortestpath = sp3[init_node, last]
            trial_s = c(trial_s, shortestpath)
        }
        s_t_matrix <- cbind(s_t_matrix, trial_s)
    }
    save(s_t_matrix, file = "./g3.RData")
} else {
    load(file = "./g3.RData")
}

# %%
s_t3 <- rowMeans(s_t_matrix)
var_t3 <- RowVar(s_t_matrix)
plot(s_t3, main="s(t) of G(10000, p=0.01)",xlab="step",ylab="avg distance",type="l")
plot(var_t3, main="var(t) of G(10000, p=0.01)",xlab="step",ylab="variance",type="l")
# Out:
# Plot with title "s(t) of G(10000, p=0.01)"
# Plot with title "var(t) of G(10000, p=0.01)"

# %%
print(s_t3[1:10])
# Out:
#  [1] 2.37 2.41 2.37 2.35 2.31 2.44 2.33 2.42 2.30 2.37

# %%
load("./g1000.RData")

# %% [markdown]
# #### 2. Random walk on networks with fat-tailed degree distribution

# %% [markdown]
# **a.**

# %%
g4 <- barabasi.game(1000, m=1, directed=F)
plot(g4,vertex.size=3, vertex.label.cex=0.3)
# Out:
# Plot with title ""

# %% [markdown]
# **b.**

# %%
set.seed(1)
tm4 <- create_transition_matrix(g4)
g4_vcount = vcount(g4)

s_t_matrix <- c()
last_deg2 <- c()
for (init_node in sample(1:g4_vcount, 100, replace=TRUE)){
    trial_s = c()
    last = init_node
    for (t in 1:300){
        PMF = tm4[last, ]
        last = sample(1:g4_vcount, 1, prob = PMF)  
        shortestpath = shortest.paths(g4, init_node, last)
        trial_s = c(trial_s, shortestpath)
    }
    last_deg2 <- c(last_deg2, degree(g4, last))
    s_t_matrix <- cbind(s_t_matrix, trial_s)
}

s_t4 <- rowMeans(s_t_matrix)
var_t4 <- RowVar(s_t_matrix)
plot(s_t4, main="s(t) of PA(1000, m=1)",xlab="step",ylab="avg distance",type="l")
plot(var_t4, main="var(t) of PA(1000, m=1)",xlab="step",ylab="variance",type="l")
# Out:
# Plot with title "s(t) of PA(1000, m=1)"
# Plot with title "var(t) of PA(1000, m=1)"

# %% [markdown]
# **c.**

# %%
hist(last_deg2, main="degree of last node",xlab="degree",ylab="number",xlim=c(0,30))
hist(degree(g4), main="degree of graph nodes",xlab="degree",ylab="number")
# Out:
# Plot with title "degree of last node"
# Plot with title "degree of graph nodes"

# %%
#d
set.seed(1)
g5 <- barabasi.game(100, m = 1, directed=F)
plot(g5,vertex.size=4, vertex.label.cex=0.3)
sp5 <- shortest.paths(g5)
g5_vcount = vcount(g5)

set.seed(1)
s_t_matrix <- c()
for (init_node in sample(1:g5_vcount, 100, replace=TRUE)){
    trial_s = c()

    last = init_node
    for (t in 1:300){
        neigh = neighbors(g5, last)
        last = sample(as_ids(neigh), 1)
        shortestpath = sp5[init_node, last]
        trial_s = c(trial_s, shortestpath)
    }
    s_t_matrix <- cbind(s_t_matrix, trial_s)
}

s_t5 <- rowMeans(s_t_matrix)
var_t5 <- RowVar(s_t_matrix)
plot(s_t5, main="s(t) of PA(100, m=1)",xlab="step",ylab="avg distance",type="l")
plot(var_t5, main="var(t) of PA(100, m=1)",xlab="step",ylab="variance",type="l")
# Out:
# Plot with title ""
# Plot with title "s(t) of PA(100, m=1)"
# Plot with title "var(t) of PA(100, m=1)"

# %%
if(!file.exists("./g6.RData")){
    set.seed(1)
    g6 <- barabasi.game(10000, m = 1, directed=F)
    # plot(g6,vertex.size=4, vertex.label.cex=0.3)
    sp6 <- shortest.paths(g6)
    g6_vcount = vcount(g6)

    set.seed(1)
    s_t_matrix <- c()
    for (init_node in sample(1:g6_vcount, 100)){
        trial_s = c()

        last = init_node
        for (t in 1:300){
            neigh = neighbors(g6, last)
            last = sample(as_ids(neigh), 1)
            shortestpath = sp6[init_node, last]
            trial_s = c(trial_s, shortestpath)
        }
        s_t_matrix <- cbind(s_t_matrix, trial_s)
    }
    save(s_t_matrix, file = "./g6.RData")
} else {
    load(file = "./g6.RData")
}
s_t6 <- rowMeans(s_t_matrix)
var_t6 <- RowVar(s_t_matrix)
plot(s_t6, main="s(t) of PA(10000, m=1)",xlab="step",ylab="avg distance",type="l")
plot(var_t6, main="var(t) of PA(10000, m=1)",xlab="step",ylab="variance",type="l")
# Out:
# Plot with title "s(t) of PA(10000, m=1)"
# Plot with title "var(t) of PA(10000, m=1)"

# %% [markdown]
# #### 2.3 PageRank

# %%
set.seed(1)
g7 = sample_pa(1000, m=4, directed=T)
plot(g7,vertex.size=4, vertex.label.cex=0.3)

tm7 = create_transition_matrix(g7)
num_steps = 100
record = rep(0, vcount(g7))
for (vstart in sample(1:vcount(g7), 100)){
    v = vstart
    for(i in 1:num_steps){
        # fprintf('Step %d: %d\n', i, v)  # COMMENT THIS
        record[v] = record[v] + 1
        PMF = tm7[v, ]
        v = sample(1:vcount(g7), 1, prob = PMF)        
    }
}
# Out:
# Plot with title ""

# %%
plot(degree(g7, mode='in'), record/num_steps/1000, main="visit probability vs degree of node (directed PA(1000, m=4))", xlab="degree of nodes", ylab="visiting probability")
# Out:
# Plot with title "visit probability vs degree of node (directed PA(1000, m=4))"

# %%
print(degree(g7)[1])
# Out:
# [1] 270

# %% [markdown]
# **2.3.b.**

# %%
record = rep(0, vcount(g7))
alpha = 0.15
tm7_1 = tm7*(1-alpha) + alpha/vcount(g7)*ones(vcount(g7))
for (vstart in sample(1:vcount(g7), 100, replace=TRUE)){
    v = vstart
    for(i in 1:num_steps){
        record[v] = record[v] + 1
        PMF = tm7_1[v, ]
        v = sample(1:vcount(g7), 1, prob = PMF)
    }
}

# %%
plot(degree(g7, mode='in'), record/num_steps/100, main="visit probability vs degree of node \n(directed PA(1000, m=4) with teleport p=0.15)", xlab="degree of nodes", ylab="visiting probability")
# Out:
# Plot with title "visit probability vs degree of node
# (directed PA(1000, m=4) with teleport p=0.15)"

# %% [markdown]
# #### 2.4 Personalized pagerank

# %%
record = rep(0, vcount(g7))
alpha = 0.15
tm7_2 = tm7*(1-alpha) + 0.15*diag(vcount(g7))

for (vstart in sample(1:vcount(g7), 100)){
    v = vstart
    for(i in 1:num_steps){
        record[v] = record[v] + 1
        PMF = tm7_2[v, ]
        v = sample(1:vcount(g7), 1, prob = PMF)
    }
}

# %%
plot(degree(g7, mode='in'), record/num_steps/100, main="Personalized pagerank \n(directed PA(1000, m=4) with teleport p=0.15)", xlab="degree of nodes", ylab="visiting probability")
# Out:
# Plot with title "Personalized pagerank
# (directed PA(1000, m=4) with teleport p=0.15)"

# %% [markdown]
# #### 2.4.b

# %%
two_med = order(record)[500:501]
print(two_medmed)
# Out:
# [1] 615 616

# %%
A = diag(vcount(g7))-(1-alpha)*tm7
b = rep(0, vcount(g7))
b[two_med] = 0.5*alpha
pagerank = solve(A, b)

# %%
print(pagerank)
# Out:
# 1000 x 1 Matrix of class "dgeMatrix"
#              [,1]
#    [1,] 0.0000000
#    [2,] 0.0000000
#    [3,] 0.0000000
#    [4,] 0.0000000
#    [5,] 0.0000000
#    [6,] 0.0000000
#    [7,] 0.0000000
#    [8,] 0.0000000
#    [9,] 0.0000000
#   [10,] 0.0000000
#   [11,] 0.0000000
#   [12,] 0.0000000
#   [13,] 0.0000000
#   [14,] 0.0000000
#   [15,] 0.0000000
#   [16,] 0.0000000
#   [17,] 0.0000000
#   [18,] 0.0000000
#   [19,] 0.0000000
#   [20,] 0.0000000
#   [21,] 0.0000000
#   [22,] 0.0000000
#   [23,] 0.0000000
#   [24,] 0.0000000
#   [25,] 0.0000000
#   [26,] 0.0000000
#   [27,] 0.0000000
#   [28,] 0.0000000
#   [29,] 0.0000000
#   [30,] 0.0000000
#   [31,] 0.0000000
#   [32,] 0.0000000
#   [33,] 0.0000000
#   [34,] 0.0000000
#   [35,] 0.0000000
#   [36,] 0.0000000
#   [37,] 0.0000000
#   [38,] 0.0000000
#   [39,] 0.0000000
#   [40,] 0.0000000
#   [41,] 0.0000000
#   [42,] 0.0000000
#   [43,] 0.0000000
#   [44,] 0.0000000
#   [45,] 0.0000000
#   [46,] 0.0000000
#   [47,] 0.0000000
#   [48,] 0.0000000
#   [49,] 0.0000000
#   [50,] 0.0000000
#   [51,] 0.0000000
#   [52,] 0.0000000
#   [53,] 0.0000000
#   [54,] 0.0000000
#   [55,] 0.0000000
#   [56,] 0.0000000
#   [57,] 0.0000000
#   [58,] 0.0000000
#   [59,] 0.0000000
#   [60,] 0.0000000
#   [61,] 0.0000000
#   [62,] 0.0000000
#   [63,] 0.0000000
#   [64,] 0.0000000
#   [65,] 0.0000000
#  [914,] 0.0000000
#  [915,] 0.0000000
#  [916,] 0.0000000
#  [917,] 0.0000000
#  [918,] 0.0000000
#  [919,] 0.0000000
#  [920,] 0.0000000
#  [921,] 0.0000000
#  [922,] 0.0000000
#  [923,] 0.0000000
#  [924,] 0.0000000
#  [925,] 0.0000000
#  [926,] 0.0000000
#  [927,] 0.0000000
#  [928,] 0.0000000
#  [929,] 0.0000000
#  [930,] 0.0000000
#  [931,] 0.0000000
#  [932,] 0.0000000
#  [933,] 0.0000000
#  [934,] 0.0000000
#  [935,] 0.0000000
#  [936,] 0.0000000
#  [937,] 0.0000000
#  [938,] 0.0000000
#  [939,] 0.0000000
#  [940,] 0.0000000
#  [941,] 0.0000000
#  [942,] 0.0000000
#  [943,] 0.0000000
#  [944,] 0.0000000
#  [945,] 0.0000000
#  [946,] 0.0000000
#  [947,] 0.0000000
#  [948,] 0.0000000
#  [949,] 0.0000000
#  [950,] 0.0000000
#  [951,] 0.0000000
#  [952,] 0.0000000
#  [953,] 0.0000000
#  [954,] 0.0000000
#  [955,] 0.0000000
#  [956,] 0.0000000
#  [957,] 0.0000000
#  [958,] 0.0000000
#  [959,] 0.0000000
#  [960,] 0.0000000
#  [961,] 0.0000000
#  [962,] 0.0000000
#  [963,] 0.0000000
#  [964,] 0.0000000
#  [965,] 0.0000000
#  [966,] 0.0000000
#  [967,] 0.0000000
#  [968,] 0.0000000
#  [969,] 0.0000000
#  [970,] 0.0000000
#  [971,] 0.0000000
#  [972,] 0.0000000
#  [973,] 0.0000000
#  [974,] 0.0000000
#  [975,] 0.0000000
#  [976,] 0.0000000
#  [977,] 0.0000000
#  [978,] 0.0000000
#  [979,] 0.0000000
#  [980,] 0.0000000
#  [981,] 0.0000000
#  [982,] 0.0000000
#  [983,] 0.0000000
#  [984,] 0.0000000
#  [985,] 0.0000000
#  [986,] 0.0000000
#  [987,] 0.0000000
#  [988,] 0.0000000
#  [989,] 0.0000000
#  [990,] 0.0000000
#  [991,] 0.0000000
#  [992,] 0.0000000
#  [993,] 0.0000000
#  [994,] 0.0000000
#  [995,] 0.0000000
#  [996,] 0.0000000
#  [997,] 0.0000000
#  [998,] 0.0000000
#  [999,] 0.0000000
# [1000,] 0.0000000

# %%
plot(degree(g7, mode='in'), pagerank, main="Personalized pagerank \n targeting two median pagerank nodes \n(directed PA(1000, m=4) with teleport p=0.15)", xlab="degree of nodes", ylab="visiting probability")
# Out:
# Plot with title "Personalized pagerank
#  targeting two median pagerank nodes
# (directed PA(1000, m=4) with teleport p=0.15)"

# %%
plot(record/10000, pagerank, 
     main="New page rank vs old page rank \n(directed PA(1000, m=4) with teleport p=0.15)", xlab="old prob", ylab="page rank")
# Out:
# Plot with title "New page rank vs old page rank
# (directed PA(1000, m=4) with teleport p=0.15)"

# %%
print(sum(pagerank))
# Out:
# [1] 0.181875

# %% [markdown]
# **c.**

# %% [markdown]
# $$ P = \begin{bmatrix} \vdots \\ t1 \\ t2 \\ \vdots \end{bmatrix} \times (1-d)+d \times M\times P$$
# where $P$ is pagerank, d is the damping factor (normally 0.85) and $M$ is the transition matrix
#
#
# $$(I-dM)P = \begin{bmatrix} \vdots \\ t1 \\ t2 \\ \vdots \end{bmatrix} \times (1-d) $$
# we may find $P$ by solving this equaiton
